# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.brightfuturesny.com/post/lying-statistics#:~:text=Key%20Lying%20Statistics,people%20lie%20on%20their%20resumes.'

response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup.find_all("title")
# Out:
# [<title>27+ Lying Statistics: The Truth About  Lying (2023)</title>]

# %% [markdown]
# ## Extract general statistics

# %%
h2 = soup.find('h2', string='Key Lying Statistics')

stats = h2.find_next('ol')

# %%
stat_tab = []

for el in stats.find_all('li'):
    stat_tab.append(el.text)
    
stat_tab
# Out:
# ['An average person lies 1-2 times a day.',
#  '60% of people lie at least once in a 10-minute conversation.',
#  'Men lie 6 times a day on average, while women lie 3 times a day on average.',
#  '40% of people lie on their resumes.',
#  '90% of people lie on their online dating profiles.',
#  '80% of women admit to lying to their partner about their spending habits.',
#  '50% of teenagers admit to lying to their parents about their whereabouts.',
#  'People are more likely to lie over the phone than face to face.',
#  '81% of people lie about their height, weight or age online.',
#  'Politicians lie on average once every five minutes during a debate.']

# %% [markdown]
# ## Extract table 'Why People Lie?'

# %%
# Find particular tables that are after given header
h2_1 = soup.find('h2', string='Why People Lie?')

# Find the next <table> element after theh 2_1
table_1 = h2_1.find_next('table')

table_1
# Out:
# <table>
# <tr>
# <th>Reason for Lying</th>
# <th>Percentage of People</th>
# </tr>
# <tr>
# <td>Fear of punishment</td>
# <td>27%</td>
# </tr>
# <tr>
# <td>To protect themselves or others from harm</td>
# <td>23%</td>
# </tr>
# <tr>
# <td>To avoid embarrassment or shame</td>
# <td>20%</td>
# </tr>
# <tr>
# <td>To gain power or advantage over others</td>
# <td>14%</td>
# </tr>
# <tr>
# <td>Out of habit or compulsion</td>
# <td>9%</td>
# </tr>
# </table>

# %%
# Extract column headers
columns = [el.text for el in table_1.find('tr').find_all('th')]

# Extract data rows
rows = []

for row in table_1.find_all('tr')[1:]:
    row_data = [td.text for td in row.find_all('td')]
    rows.append(row_data)

# %%
# Create a DataFrame
tab_1 = pd.DataFrame(rows, columns=columns)

pd.set_option('display.max_colwidth', None)

display(tab_1)
# Out:
#                             Reason for Lying Percentage of People
# 0                         Fear of punishment                  27%
# 1  To protect themselves or others from harm                  23%
# 2            To avoid embarrassment or shame                  20%
# 3     To gain power or advantage over others                  14%
# 4                 Out of habit or compulsion                   9%

# %% [markdown]
# ## Extract table 'Who Do People Lie To?'

# %%
h2_2 = soup.find('h2', string='Who Do People Lie To?')

table_2 = h2_2.find_next('table')


# Extract table data
columns_2 = [el.text for el in table_2.find('tr').find_all('th')]

rows_2 = []

for row in table_2.find_all('tr')[1:]:
    row_data = [td.text for td in row.find_all('td')]
    rows_2.append(row_data)
    
# Create a DataFrame
tab_2 = pd.DataFrame(rows_2, columns=columns_2)

pd.set_option('display.max_colwidth', None)

display(tab_2)
# Out:
#   Recipient of the Lie Percentage of People
# 0   Boss or supervisor                  56%
# 1    Significant other                  42%
# 2              Friends                  39%
# 3  Healthcare provider                  28%
# 4             Children                  23%
# 5      Job application                  18%

# %% [markdown]
# ## Extract table 'Most Common Types of Lies People Tell - Statistics and Insights'

# %%
h2_3 = soup.find('h2', string='Most Common Types of Lies People Tell - Statistics and Insights')

table_3 = h2_3.find_next('table')


# Extract table data
columns_3 = [el.text for el in table_3.find('tr').find_all('th')]

rows_3 = []

for row in table_3.find_all('tr')[1:]:
    row_data = [td.text for td in row.find_all('td')]
    rows_3.append(row_data)
    
# Create a DataFrame
tab_3 = pd.DataFrame(rows_3, columns=columns_3)

pd.set_option('display.max_colwidth', None)

display(tab_3)
# Out:
#                            Type of Lie Percentage of People
# 0                           White lies                  72%
# 1  Lies about personal accomplishments                  64%
# 2            Lies about their emotions                  63%
# 3         Lies about their whereabouts                  60%

# %% [markdown]
# ## Facial-action-coding-system

# %%
url_2 = 'https://imotions.com/blog/learning/research-fundamentals/facial-action-coding-system/'

response_2 = requests.get(url_2)

# %%
response_2
# Out:
# <Response [200]>

# %% [markdown]
# **Main action units**

# %%
soup_2 = BeautifulSoup(response_2.content, "html.parser")

# %%
table_2 = soup_2.find('table', {'class': 'has-border-color has-cyan-bluish-gray-border-color'})

df = pd.read_html(str(table_2))[0]

# %%
img_tags = soup_2.find_all('img')

src_links = [img['src'] for img in img_tags]

gifs =[]
for el in src_links:
    if el.split('.')[-1]=='gif':
        gifs.append(el)

# %%
gifs_in_tab = gifs[0:30]

# %%
df['Example'] = gifs_in_tab

# %%
df.head(4)
# Out:
#   Action Unit                                 Description  \
# 0           1                           Inner Brow Raiser
# 1           2  Outer Brow Raiser (unilateral, right side)
# 2           4                                Brow Lowerer
# 3           5                            Upper Lid Raiser
#
#                                        Facial Muscle  \
# 0                           Frontalis, pars medialis
# 1                          Frontalis, pars lateralis
# 2  Depressor Glabellae, Depressor Supercilli, Cur...
# 3                       Levator palpebrae superioris
#
#                                              Example
# 0  https://imotions.com/wp-content/uploads/2022/1...
# 1  https://imotions.com/wp-content/uploads/2022/1...
# 2  https://imotions.com/wp-content/uploads/2022/1...
# 3  https://imotions.com/wp-content/uploads/2022/1...

# %% [markdown]
# **Action units associated with emotions**

# %%
# Find particular tables that are after given header
h2 = soup_2.find('h2', string='Emotions and Action Units')

table_3 = h2.find_next('table', {'class': 'has-border-color has-cyan-bluish-gray-border-color'})

# %%
df_2 = pd.read_html(str(table_3), header=0)[0]

# %%
df_2 = df_2.drop('Examples', axis=1)

# %%
df_2
# Out:
#            Emotion                       Action Units  \
# 0  Happiness / Joy                             6 + 12
# 1          Sadness                         1 + 4 + 15
# 2         Surprise                     1 + 2 + 5 + 26
# 3             Fear        1 + 2 + 4 + 5 + 7 + 20 + 26
# 4            Anger                     4 + 5 + 7 + 23
# 5          Disgust                        9 + 15 + 16
# 6         Contempt  12 + 14 (on one side of the face)
#
#                                          Description
# 0                    Cheek Raiser, Lip Corner Puller
# 1  Inner Brow Raiser, Brow Lowerer, Lip Corner De...
# 2  Inner Brow Raiser, Outer Brow Raiser, Upper Li...
# 3  Inner Brow Raiser, Outer Brow Raiser, Brow Low...
# 4  Brow Lowerer, Upper Lid Raiser, Lid Tightener,...
# 5  Nose Wrinkler, Lip Corner Depressor, Lower Lip...
# 6                         Lip Corner Puller, Dimpler

# %%
df_2['Action Units'] = df_2['Action Units'].apply(lambda x: [item.strip() for item in x.split('+')])

# %%
df_2
# Out:
#            Emotion                        Action Units  \
# 0  Happiness / Joy                             [6, 12]
# 1          Sadness                          [1, 4, 15]
# 2         Surprise                       [1, 2, 5, 26]
# 3             Fear             [1, 2, 4, 5, 7, 20, 26]
# 4            Anger                       [4, 5, 7, 23]
# 5          Disgust                         [9, 15, 16]
# 6         Contempt  [12, 14 (on one side of the face)]
#
#                                          Description
# 0                    Cheek Raiser, Lip Corner Puller
# 1  Inner Brow Raiser, Brow Lowerer, Lip Corner De...
# 2  Inner Brow Raiser, Outer Brow Raiser, Upper Li...
# 3  Inner Brow Raiser, Outer Brow Raiser, Brow Low...
# 4  Brow Lowerer, Upper Lid Raiser, Lid Tightener,...
# 5  Nose Wrinkler, Lip Corner Depressor, Lower Lip...
# 6                         Lip Corner Puller, Dimpler

# %%
df_2['Action Units'][6] = ['12', '14']

# %%
df_2.rename(columns={'Emotion': 'emotion', 'Action Units': 'action_units', 'Description' :  'description'}, inplace=True)

# %%
df_2
# Out:
#            emotion             action_units  \
# 0  Happiness / Joy                  [6, 12]
# 1          Sadness               [1, 4, 15]
# 2         Surprise            [1, 2, 5, 26]
# 3             Fear  [1, 2, 4, 5, 7, 20, 26]
# 4            Anger            [4, 5, 7, 23]
# 5          Disgust              [9, 15, 16]
# 6         Contempt                 [12, 14]
#
#                                          description
# 0                    Cheek Raiser, Lip Corner Puller
# 1  Inner Brow Raiser, Brow Lowerer, Lip Corner De...
# 2  Inner Brow Raiser, Outer Brow Raiser, Upper Li...
# 3  Inner Brow Raiser, Outer Brow Raiser, Brow Low...
# 4  Brow Lowerer, Upper Lid Raiser, Lid Tightener,...
# 5  Nose Wrinkler, Lip Corner Depressor, Lower Lip...
# 6                         Lip Corner Puller, Dimpler

# %%
df_exploded = df_2.explode(['action_units'])

# %%
df_exploded
# Out:
#            emotion action_units  \
# 0  Happiness / Joy            6
# 0  Happiness / Joy           12
# 1          Sadness            1
# 1          Sadness            4
# 1          Sadness           15
# 2         Surprise            1
# 2         Surprise            2
# 2         Surprise            5
# 2         Surprise           26
# 3             Fear            1
# 3             Fear            2
# 3             Fear            4
# 3             Fear            5
# 3             Fear            7
# 3             Fear           20
# 3             Fear           26
# 4            Anger            4
# 4            Anger            5
# 4            Anger            7
# 4            Anger           23
# 5          Disgust            9
# 5          Disgust           15
# 5          Disgust           16
# 6         Contempt           12
# 6         Contempt           14
#
#                                          description
# 0                    Cheek Raiser, Lip Corner Puller
# 0                    Cheek Raiser, Lip Corner Puller
# 1  Inner Brow Raiser, Brow Lowerer, Lip Corner De...
# 1  Inner Brow Raiser, Brow Lowerer, Lip Corner De...
# 1  Inner Brow Raiser, Brow Lowerer, Lip Corner De...
# 2  Inner Brow Raiser, Outer Brow Raiser, Upper Li...
# 2  Inner Brow Raiser, Outer Brow Raiser, Upper Li...
# 2  Inner Brow Raiser, Outer Brow Raiser, Upper Li...
# 2  Inner Brow Raiser, Outer Brow Raiser, Upper Li...
# 3  Inner Brow Raiser, Outer Brow Raiser, Brow Low...
# 3  Inner Brow Raiser, Outer Brow Raiser, Brow Low...
# 3  Inner Brow Raiser, Outer Brow Raiser, Brow Low...
# 3  Inner Brow Raiser, Outer Brow Raiser, Brow Low...
# 3  Inner Brow Raiser, Outer Brow Raiser, Brow Low...
# 3  Inner Brow Raiser, Outer Brow Raiser, Brow Low...
# 3  Inner Brow Raiser, Outer Brow Raiser, Brow Low...
# 4  Brow Lowerer, Upper Lid Raiser, Lid Tightener,...
# 4  Brow Lowerer, Upper Lid Raiser, Lid Tightener,...
# 4  Brow Lowerer, Upper Lid Raiser, Lid Tightener,...
# 4  Brow Lowerer, Upper Lid Raiser, Lid Tightener,...
# 5  Nose Wrinkler, Lip Corner Depressor, Lower Lip...
# 5  Nose Wrinkler, Lip Corner Depressor, Lower Lip...
# 5  Nose Wrinkler, Lip Corner Depressor, Lower Lip...
# 6                         Lip Corner Puller, Dimpler
# 6                         Lip Corner Puller, Dimpler

# %%
emotion_map = {'Anger' : 0, 'Disgust' : 1, 'Fear' : 2, 'Happiness / Joy' : 3, 'Sadness' : 4, 'Surprise' : 5, 'Contempt' : 7}

df_exploded['emotion'] = df_exploded['emotion'].map(emotion_map)

# %%
df_exploded.rename({'emotion' : 'emotion_id'}, inplace=True)

# %%
df_exploded.drop(columns = ['description'], inplace=True)

# %%
df.rename(columns={'Action Unit': 'action_unit', 'Description' :  'description', 'Facial Muscle': 'facial_muscle', 'Example' : 'example'}, inplace = True)

# %%
df
# Out:
#                            action_unit  \
# 0                                    1
# 1                                    2
# 2                                    4
# 3                                    5
# 4                                    6
# 5                                    7
# 6   9 (also shows slight AU4 and AU10)
# 7          10 (also shows slight AU25)
# 8                                   11
# 9                                   12
# 10                                  13
# 11                                  14
# 12                                  15
# 13                      16 (with AU25)
# 14                                  17
# 15      18 (with slight AU22 and AU25)
# 16                                  20
# 17                      22 (with AU25)
# 18                                  23
# 19                                  24
# 20                                  25
# 21                      26 (with AU25)
# 22                                  27
# 23                      28 (with AU26)
# 24                                  41
# 25                                  42
# 26                                  43
# 27                                  44
# 28                                  45
# 29                                  46
#
#                                    description  \
# 0                            Inner Brow Raiser
# 1   Outer Brow Raiser (unilateral, right side)
# 2                                 Brow Lowerer
# 3                             Upper Lid Raiser
# 4                                 Cheek Raiser
# 5                                Lid Tightener
# 6                                Nose Wrinkler
# 7                             Upper Lip Raiser
# 8                          Nasolabial Deepener
# 9                            Lip Corner Puller
# 10                                Cheek Puffer
# 11                                     Dimpler
# 12                        Lip Corner Depressor
# 13                         Lower Lip Depressor
# 14                                 Chin Raiser
# 15                                Lip Puckerer
# 16                               Lip stretcher
# 17                                Lip Funneler
# 18                               Lip Tightener
# 19                                 Lip Pressor
# 20                                   Lips part
# 21                                    Jaw Drop
# 22                               Mouth Stretch
# 23                                    Lip Suck
# 24                                   Lid droop
# 25                                        Slit
# 26                                 Eyes Closed
# 27                                      Squint
# 28                                       Blink
# 29                                        Wink
#
#                                         facial_muscle  \
# 0                            Frontalis, pars medialis
# 1                           Frontalis, pars lateralis
# 2   Depressor Glabellae, Depressor Supercilli, Cur...
# 3                        Levator palpebrae superioris
# 4                   Orbicularis oculi, pars orbitalis
# 5                 Orbicularis oculi, pars palpebralis
# 6               Levator labii superioris alaquae nasi
# 7      Levator Labii Superioris, Caput infraorbitalis
# 8                                     Zygomatic Minor
# 9                                     Zygomatic Major
# 10                      Levator anguli oris (Caninus)
# 11                                         Buccinator
# 12               Depressor anguli oris (Triangularis)
# 13                         Depressor labii inferioris
# 14                                           Mentalis
# 15  Incisivii labii superioris and Incisivii labii...
# 16                                           Risorius
# 17                                   Orbicularis oris
# 18                                   Orbicularis oris
# 19                                   Orbicularis oris
# 20  Depressor Labii, Relaxation of Mentalis (AU17)...
# 21  Masetter; Temporal and Internal Pterygoid relaxed
# 22                              Pterygoids, Digastric
# 23                                   Orbicularis oris
# 24         Relaxation of Levator Palpebrae Superioris
# 25                                  Orbicularis oculi
# 26         Relaxation of Levator Palpebrae Superioris
# 27                Orbicularis oculi, pars palpebralis
# 28  Relaxation of Levator Palpebrae and Contractio...
# 29  Levator palpebrae superioris; Orbicularis ocul...
#
#                                               example
# 0   https://imotions.com/wp-content/uploads/2022/1...
# 1   https://imotions.com/wp-content/uploads/2022/1...
# 2   https://imotions.com/wp-content/uploads/2022/1...
# 3   https://imotions.com/wp-content/uploads/2022/1...
# 4   https://imotions.com/wp-content/uploads/2022/1...
# 5   https://imotions.com/wp-content/uploads/2022/1...
# 6   https://imotions.com/wp-content/uploads/2022/1...
# 7   https://imotions.com/wp-content/uploads/2022/1...
# 8   https://imotions.com/wp-content/uploads/2022/1...
# 9   https://imotions.com/wp-content/uploads/2022/1...
# 10  https://imotions.com/wp-content/uploads/2022/1...
# 11  https://imotions.com/wp-content/uploads/2022/1...
# 12  https://imotions.com/wp-content/uploads/2022/1...
# 13  https://imotions.com/wp-content/uploads/2022/1...
# 14  https://imotions.com/wp-content/uploads/2022/1...
# 15  https://imotions.com/wp-content/uploads/2022/1...
# 16  https://imotions.com/wp-content/uploads/2022/1...
# 17  https://imotions.com/wp-content/uploads/2022/1...
# 18  https://imotions.com/wp-content/uploads/2022/1...
# 19  https://imotions.com/wp-content/uploads/2022/1...
# 20  https://imotions.com/wp-content/uploads/2022/1...
# 21  https://imotions.com/wp-content/uploads/2022/1...
# 22  https://imotions.com/wp-content/uploads/2022/1...
# 23  https://imotions.com/wp-content/uploads/2022/1...
# 24  https://imotions.com/wp-content/uploads/2022/1...
# 25  https://imotions.com/wp-content/uploads/2022/1...
# 26  https://imotions.com/wp-content/uploads/2022/1...
# 27  https://imotions.com/wp-content/uploads/2022/1...
# 28  https://imotions.com/wp-content/uploads/2022/1...
# 29  https://imotions.com/wp-content/uploads/2022/1...

# %%
# Cleaning some values 

df['action_unit'][6] = 9
df['action_unit'][7] = 10
df['action_unit'][13] = 16
df['action_unit'][15] = 18
df['action_unit'][17] = 22
df['action_unit'][21] = 26
df['action_unit'][23] = 28

# %%
df
# Out:
#    action_unit                                 description  \
# 0            1                           Inner Brow Raiser
# 1            2  Outer Brow Raiser (unilateral, right side)
# 2            4                                Brow Lowerer
# 3            5                            Upper Lid Raiser
# 4            6                                Cheek Raiser
# 5            7                               Lid Tightener
# 6            9                               Nose Wrinkler
# 7           10                            Upper Lip Raiser
# 8           11                         Nasolabial Deepener
# 9           12                           Lip Corner Puller
# 10          13                                Cheek Puffer
# 11          14                                     Dimpler
# 12          15                        Lip Corner Depressor
# 13          16                         Lower Lip Depressor
# 14          17                                 Chin Raiser
# 15          18                                Lip Puckerer
# 16          20                               Lip stretcher
# 17          22                                Lip Funneler
# 18          23                               Lip Tightener
# 19          24                                 Lip Pressor
# 20          25                                   Lips part
# 21          26                                    Jaw Drop
# 22          27                               Mouth Stretch
# 23          28                                    Lip Suck
# 24          41                                   Lid droop
# 25          42                                        Slit
# 26          43                                 Eyes Closed
# 27          44                                      Squint
# 28          45                                       Blink
# 29          46                                        Wink
#
#                                         facial_muscle  \
# 0                            Frontalis, pars medialis
# 1                           Frontalis, pars lateralis
# 2   Depressor Glabellae, Depressor Supercilli, Cur...
# 3                        Levator palpebrae superioris
# 4                   Orbicularis oculi, pars orbitalis
# 5                 Orbicularis oculi, pars palpebralis
# 6               Levator labii superioris alaquae nasi
# 7      Levator Labii Superioris, Caput infraorbitalis
# 8                                     Zygomatic Minor
# 9                                     Zygomatic Major
# 10                      Levator anguli oris (Caninus)
# 11                                         Buccinator
# 12               Depressor anguli oris (Triangularis)
# 13                         Depressor labii inferioris
# 14                                           Mentalis
# 15  Incisivii labii superioris and Incisivii labii...
# 16                                           Risorius
# 17                                   Orbicularis oris
# 18                                   Orbicularis oris
# 19                                   Orbicularis oris
# 20  Depressor Labii, Relaxation of Mentalis (AU17)...
# 21  Masetter; Temporal and Internal Pterygoid relaxed
# 22                              Pterygoids, Digastric
# 23                                   Orbicularis oris
# 24         Relaxation of Levator Palpebrae Superioris
# 25                                  Orbicularis oculi
# 26         Relaxation of Levator Palpebrae Superioris
# 27                Orbicularis oculi, pars palpebralis
# 28  Relaxation of Levator Palpebrae and Contractio...
# 29  Levator palpebrae superioris; Orbicularis ocul...
#
#                                               example
# 0   https://imotions.com/wp-content/uploads/2022/1...
# 1   https://imotions.com/wp-content/uploads/2022/1...
# 2   https://imotions.com/wp-content/uploads/2022/1...
# 3   https://imotions.com/wp-content/uploads/2022/1...
# 4   https://imotions.com/wp-content/uploads/2022/1...
# 5   https://imotions.com/wp-content/uploads/2022/1...
# 6   https://imotions.com/wp-content/uploads/2022/1...
# 7   https://imotions.com/wp-content/uploads/2022/1...
# 8   https://imotions.com/wp-content/uploads/2022/1...
# 9   https://imotions.com/wp-content/uploads/2022/1...
# 10  https://imotions.com/wp-content/uploads/2022/1...
# 11  https://imotions.com/wp-content/uploads/2022/1...
# 12  https://imotions.com/wp-content/uploads/2022/1...
# 13  https://imotions.com/wp-content/uploads/2022/1...
# 14  https://imotions.com/wp-content/uploads/2022/1...
# 15  https://imotions.com/wp-content/uploads/2022/1...
# 16  https://imotions.com/wp-content/uploads/2022/1...
# 17  https://imotions.com/wp-content/uploads/2022/1...
# 18  https://imotions.com/wp-content/uploads/2022/1...
# 19  https://imotions.com/wp-content/uploads/2022/1...
# 20  https://imotions.com/wp-content/uploads/2022/1...
# 21  https://imotions.com/wp-content/uploads/2022/1...
# 22  https://imotions.com/wp-content/uploads/2022/1...
# 23  https://imotions.com/wp-content/uploads/2022/1...
# 24  https://imotions.com/wp-content/uploads/2022/1...
# 25  https://imotions.com/wp-content/uploads/2022/1...
# 26  https://imotions.com/wp-content/uploads/2022/1...
# 27  https://imotions.com/wp-content/uploads/2022/1...
# 28  https://imotions.com/wp-content/uploads/2022/1...
# 29  https://imotions.com/wp-content/uploads/2022/1...

# %%
df.to_csv('csv_files/facs_single_units.csv', index=False)

# %%
df_exploded.to_csv('csv_files/facs_emotions_units.csv', index=False)
